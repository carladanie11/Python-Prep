# %% [markdown]
# # Variables

# %%
# Este es un comentario
2 + 2
# Out:
# 4

# %%
caja = 28

# %%
print(caja)
# Out:
# 28

# %%
caja
# Out:
# 28

# %%
variable = "Mi primera variable"
print(variable)
# Out:
# Mi primera variable

# %%
variable_2 = 25 # variables se escriben con minusculas
print(variable_2)
# Out:
# 25

# %% [markdown]
# # Tipos de datos

# %%
entero = 45
print(entero)
# Out:
# 45

# %%
type(entero)
# Out:
# int

# %%
caracteres = "Hola, mundo"
print(caracteres)
# Out:
# Hola, mundo

# %%
type(caracteres)
# Out:
# str

# %%
flotante = 4.5
print(flotante)
# Out:
# 4.5

# %%
type(flotante)
# Out:
# float

# %%
booleano = True
print(booleano)
# Out:
# True

# %%
type(booleano)
# Out:
# bool

# %%
complejo = 4 + 5j
print(complejo)
# Out:
# (4+5j)

# %%
type(complejo)
# Out:
# complex

# %% [markdown]
# # Operaciones entre variables

# %%
a = 4
b = 5
a + b
# Out:
# 9

# %%
b - a
# Out:
# 1

# %%
b * a
# Out:
# 20

# %%
17 / 5
# Out:
# 3.4

# %%
17 // 5
# Out:
# 3

# %%
17 % 5
# Out:
# 2

# %%
4 **2
# Out:
# 16

# %% [markdown]
# # Operaciones de asignacion

# %%
mi_edad = 28

# %%
mi_edad = "28 años"

# %%
print(mi_edad)
# Out:
# 28 años

# %%
mi_edad = 28

# %%
mi_edad = mi_edad +1
print(mi_edad)
# Out:
# 29

# %%
mi_edad = 28
mi_edad += 1
print(mi_edad)
# Out:
# 29

# %%
años_jubilacion = 35
años_jubilacion -= 1
print(años_jubilacion)
# Out:
# 34

# %% [markdown]
# # Operaciones relacionales

# %%
20 == 19
# Out:
# False

# %%
20 != 19
# Out:
# True

# %%
20>=19
# Out:
# True

# %%
20<=19
# Out:
# False

# %%
"Estoy " + "Feliz de aprender " + "Python"
# Out:
# 'Estoy Feliz de aprender Python'

# %%
"ja,ja " * 3
# Out:
# 'ja,ja ja,ja ja,ja '

# %% [markdown]
# # Conversion tipo de datos

# %%
a = "5"
print(a)
# Out:
# 5

# %%
type(a)
# Out:
# str

# %%
int(a)
# Out:
# 5

# %%
type (a)
# Out:
# str

# %%
b = int(a)
print(b)
type(b)
# Out:
# 5
# int

# %%
nombre = "Carla"
int(nombre)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 2
#       1 nombre = "Carla"
# ----> 2 int(nombre)
#
# ValueError: invalid literal for int() with base 10: 'Carla'

# %%
b = '5.6'
print(type(b))
b = float(b)
print(type(b))
# Out:
# <class 'str'>
# <class 'float'>

# %%
str(5.6)
# Out:
# '5.6'
